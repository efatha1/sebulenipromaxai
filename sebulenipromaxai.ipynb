# %%
# !pip install -r /kaggle/working/sebulenipromaxai/requirements.txt

# %%
# !pip install -r /kaggle/working/sebulenipromaxai/requirements-dev.txt

# %%
# !pip install -q pydrive2

# %%
from pydrive2.auth import GoogleAuth
from pydrive2.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
import os

# Authenticate
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

print("✅ Google Drive authentication successful!")
# Out:
# ✅ Google Drive authentication successful!

# %%
# !git clone https://github.com/efatha1/sebulenipromaxai
# Out:
# Cloning into 'sebulenipromaxai'...
# remote: Enumerating objects: 331, done.
# remote: Counting objects: 100% (331/331), done.
# remote: Compressing objects: 100% (291/291), done.
# remote: Total 331 (delta 53), reused 308 (delta 34), pack-reused 0 (from 0)
# Receiving objects: 100% (331/331), 574.16 KiB | 10.25 MiB/s, done.
# Resolving deltas: 100% (53/53), done.
